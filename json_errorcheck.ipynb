# %%
import json

# %%
with open("C:/Users/USER/Desktop/joo/project/working/use_json/json/ex_region_data6.json", 'r') as f:
    json_data = json.load(f)
print(json.dumps(json_data, indent="\t"))
# Out:
# {
# 	"GEN_65226.png219506": {
# 		"fileref": "",
# 		"size": 219506,
# 		"filename": "GEN_65226.png",
# 		"base64_img_data": "",
# 		"file_attributes": {},
# 		"regions": {
# 			"0": {
# 				"shape_attributes": {
# 					"name": "polygon",
# 					"all_points_x": [
# 						184,
# 						184,
# 						181,
# 						201,
# 						202,
# 						184
# 					],
# 					"all_points_y": [
# 						355,
# 						356,
# 						377,
# 						378,
# 						356,
# 						355
# 					]
# 				},
# 				"region_attributes": {
# 					"name": "F2542"
# 				}
# 			},
# 			"1": {
# 				"shape_attributes": {
# 					"name": "polygon",
# 					"all_points_x": [
# 						706,
# 						714,
# 						717,
# 						717,
# 						714,
# 						709,
# 						697,
# 						693,
# 						691,
# 						692,
# 						695,
# 						706
# 					],
# 					"all_points_y": [
# 						367,
# 						373,
# 						379,
# 						386,
# 						388,
# 						392,
# 						393,
# 						385,
# 						381,
# 						374,
# 						370,
# 						367
# 					]
# 				},
# ...

# %%
ano = list(json_data.values())

# %%
ano = [a for a in ano if a['regions']]

# %%
for a in ano:
    objects = [s['region_attributes'] for s in a['regions'].values()]
    #print(objects)
    
    #for key in objects:
    #    print(key)
        
    
    for i in objects:
        #print(i['name'])
        if(not(i['name']=='F1111'or i['name']=='F1112'or i['name']=='F2511'or i['name']=='F1322'or i['name']=='F2542'or i['name']=='F3342'or i['name']=='F6110'or i['name']=='F2240'or i['name']=='F3130'or i['name']=='F3330')):
            print(i['name'])
